# %% [markdown]
# # Introduction to the LlamaHub
#
# **LlamaHub is a registry of hundreds of integrations, agents and tools that you can use within LlamaIndex.**
#
# ![LlamaHub](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/unit2/llama-index/llama-hub.png)
#
# We will be using various integrations in this course, so let's first look at the LlamaHub and how it can help us.
#
# Let's see how to find and install the dependencies for the components we need.
#
# ## Installation
#
# LlamaIndex installation instructions are available as a well-structured **overview on [LlamaHub](https://llamahub.ai/)**.
# This might be a bit overwhelming at first, but most of the **installation commands generally follow an easy-to-remember format**:
#
# ```bash
# pip install llama-index-{component-type}-{framework-name}
# ```
#
# Let's try to install the dependencies for an LLM and embedding component using the [Hugging Face inference API integration](https://llamahub.ai/l/llms/llama-index-llms-huggingface-api?from=llms).
#
# ```bash
# pip install llama-index-llms-huggingface-api llama-index-embeddings-huggingface
# ```
#
# ## Usage
#
# Once installed, we can see the usage patterns. You'll notice that the import paths follow the install command!
# Underneath, we can see an example of the usage of **the Hugging Face inference API for an LLM component**.
#
# ```python
# from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
# import os
# from dotenv import load_dotenv
#
# # Load the .env file
# load_dotenv()
#
# # Retrieve HF_TOKEN from the environment variables
# hf_token = os.getenv("HF_TOKEN")
#
# llm = HuggingFaceInferenceAPI(
#     model_name="Qwen/Qwen2.5-Coder-32B-Instruct",
#     temperature=0.7,
#     max_tokens=100,
#     token=hf_token,
#     provider="auto"
# )
#
# response = llm.complete("Hello, how are you?")
# print(response)
# # I am good, how can I help you today?
# ```
#
# Wonderful, we now know how to find, install and use the integrations for the components we need.
# **Let's dive deeper into the components** and see how we can use them to build our own agents.

# %% [markdown]
# Let's run above code one by one

# %%
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
import os
from dotenv import load_dotenv

# Load the .env file
load_dotenv()

# Retrieve HF_TOKEN from the environment variables
hf_token = os.getenv("HF_TOKEN")

llm = HuggingFaceInferenceAPI(
    model_name="Qwen/Qwen2.5-Coder-32B-Instruct",
    temperature=0.7,
    max_tokens=100,
    token=hf_token
)

response = llm.complete("Hello, how are you?")
print(response)
# I am good, how can I help you today?
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://router.huggingface.co/hf-inference/models/Qwen/Qwen2.5-Coder-32B-Instruct/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[1], line 18
#       9 hf_token = os.getenv("HF_TOKEN")
#      11 llm = HuggingFaceInferenceAPI(
#      12     model_name="Qwen/Qwen2.5-Coder-32B-Instruct",
#      13     temperature=0.7,
#      14     max_tokens=100,
#      15     token=hf_token
#      16 )
# ---> 18 response = llm.complete("Hello, how are you?")
#      19 print(response)
#      20 # I am good, how can I help you today?
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\llama_index\llms\huggingface_api\base.py:314, in HuggingFaceInferenceAPI.complete(self, prompt, formatted, **kwargs)
#     310 def complete(
#     311     self, prompt: str, formatted: bool = False, **kwargs: Any
#     312 ) -> CompletionResponse:
#     313     if self.task == "conversational":
# --> 314         chat_resp = self.chat(
#     315             messages=[ChatMessage(role=MessageRole.USER, content=prompt)], **kwargs
#     316         )
#     317         return chat_response_to_completion_response(chat_resp)
#     319     model_kwargs = self._get_model_kwargs(**kwargs)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\llama_index_instrumentation\dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\llama_index\llms\huggingface_api\base.py:287, in HuggingFaceInferenceAPI.chat(self, messages, **kwargs)
#     284 if self.task == "conversational" or self.task is None:
#     285     model_kwargs = self._get_model_kwargs(**kwargs)
# --> 287     output: ChatCompletionOutput = self._sync_client.chat_completion(
#     288         messages=self._to_huggingface_messages(messages),
#     289         **model_kwargs,
#     290     )
#     292     content = output.choices[0].message.content or ""
#     293     tool_calls = output.choices[0].message.tool_calls or []
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:919, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     891 parameters = {
#     892     "model": payload_model,
#     893     "frequency_penalty": frequency_penalty,
#    (...)    910     **(extra_body or {}),
#     911 }
#     912 request_parameters = provider_helper.prepare_request(
#     913     inputs=messages,
#     914     parameters=parameters,
#    (...)    917     api_key=self.token,
#     918 )
# --> 919 data = self._inner_post(request_parameters, stream=stream)
#     921 if stream:
#     922     return _stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:275, in InferenceClient._inner_post(self, request_parameters, stream)
#     272     raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     274 try:
# --> 275     hf_raise_for_status(response)
#     276     return response.iter_lines() if stream else response.content
#     277 except HTTPError as error:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     478     raise _format(HfHubHTTPError, message, response) from e
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 404 Client Error: Not Found for url: https://router.huggingface.co/hf-inference/models/Qwen/Qwen2.5-Coder-32B-Instruct/v1/chat/completions (Request ID: Root=1-69605fd6-594bdfd83b69ebf41c6c63c9;b2fe4a9e-12f5-43b0-aa5e-451bb5ece81c)

# %% [markdown]
# Hugginface Inference has expired, trying with ollama locally

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="llava:latest", base_url='http://127.0.0.1:11434')
response = llm.complete("Hello, how are you?")
print(response)
# Out:
#  Hello! I'm just a computer program, so I don't have feelings or emotions. How can I help you today?

# %%
llm = Ollama(model="kimi-k2:1t-cloud", base_url='http://127.0.0.1:11434')
response = llm.complete("Hello, how are you?")
print(response)
# Out:
# Hello! I'm doing well—thanks for asking. How about you?
