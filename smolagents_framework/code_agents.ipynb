# %% [markdown]
# # Building Agents That Use Code
#
# This notebook is part of the [Hugging Face Agents Course](https://www.hf.co/learn/agents-course), a free Course from beginner to expert, where you learn to build Agents.
#
# ![Agents course share](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/communication/share.png)
#
# Alfred is planning a party at the Wayne family mansion and needs your help to ensure everything goes smoothly. To assist him, we'll apply what we've learned about how a multi-step `CodeAgent` operates.

# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API
#
# If you haven't installed `smolagents` yet, you can do so by running the following command:

# %%
# !pip install smolagents -U
# Out:
# Requirement already satisfied: smolagents in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (1.23.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents) (0.35.0)
# Requirement already satisfied: requests>=2.32.3 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents) (14.1.0)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents) (11.1.0)
# Requirement already satisfied: python-dotenv in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents) (1.1.1)
# Requirement already satisfied: filelock in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from jinja2>=3.1.4->smolagents) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from rich>=13.9.4->smolagents) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from rich>=13.9.4->smolagents) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: colorama in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.31.2->smolagents) (0.4.6)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Let's also login to the Hugging Face Hub to have access to the Inference API.

# %%
from huggingface_hub import login
import os 
from dotenv import load_dotenv
load_dotenv()
login(token=os.environ.get('HF_TOKEN'))
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Selecting a Playlist for the Party Using `smolagents`
#
# An important part of a successful party is the music. Alfred needs some help selecting the playlist. Luckily, `smolagents` has got us covered! We can build an agent capable of searching the web. To give the agent access to this tool, we include it in the tool list when creating the agent.
#
# For the model, we'll rely on `InferenceClientModel`, which provides access to Hugging Face's [Inference API](https://huggingface.co/docs/api-inference/index). The default model is `"Qwen/Qwen2.5-Coder-32B-Instruct"`, which is performant and available for fast inference, but you can select any compatible model from the Hub.
#
# Running an agent is quite straightforward:

# %%
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel

agent = CodeAgent(tools=[WebSearchTool()], model=InferenceClientModel())

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music recommendations for party at Wayne's mansion")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [late nights in the wayne manor | a bruce wayne rock/blues playlist](https://www.youtube.com/watch?v=oOdHCjj3jn4)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne manor. find this playlist
# on my spotify: https://open.spotify.com/user ...
#
# [waynes world! party time! excellent!! - playlist by whit |
# Spotify](https://open.spotify.com/playlist/6f7pPhnr9Tq9wVA1FvC8iO)
# whit · Playlist · 380 songs · 17 likes
#
# [The 75 Best Party Songs That Will Get Everyone Dancing -
# Gear4music](https://www.gear4music.com/blog/best-party-songs/)
# Creating the perfect soundtrack is crucial to getting the right atmosphere at your event. If you're throwing a
# party , there are countless songs that will get everyone up and dancing; even once you've chosen your mix, you'll
# probably still think of more later! So, to keep things simple, we've compiled the best  party songs of all time,
# from timeless classics to contemporary hits, giving ...
#
# [The 50 Best Music Playlists for Parties [2025] - Playlist
# Names](https://www.playlistnames.org/best-music-playlists-for-parties/)
# Are you ready to turn your next gathering into an unforgettable bash? 🎊 The right music can elevate any party ,
# transforming it from a simple get-together into a full-blown celebration! In this article, we've curated a list of
# 50 best  music playlists for parties that will keep your guests dancing all night long.
#
# [Best Songs To Party: DJ's Ultimate Party Songs Playlist](https://top40weekly.com/best-songs-to-party/)
# Planning a celebration? Don't forget the music ! We've compiled the best songs to party that are sure to get
# everyone in the mood to dance and have a good time.
#
# [The Ultimate Playlist to Get the Party Started](https://alekasgettogether.com/top-songs-for-any-party/)
# Discover the ultimate party playlist for 2025 with over 50 top songs to keep your guests dancing all night long.
#
# [late nights in the wayne manor - YouTube Music](https://music.youtube.com/watch?v=oOdHCjj3jn4)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne manor. find this playlist
# on my spotify: https://open.spotify.com/u...
#
# [GUIDE TO Planning Music for a Party -
# partiesuniverse.com](https://partiesuniverse.com/guide-to-planning-music-for-a-party/)
# There are relatively few high-quality guides about how to plan brilliant music  for a party , so we have decided to
# create our own. Our how-to guide for planning the best  music  for a party , is exactly what you need to throw an
# epic celebration where the music completely carries the vibe.
#
# [Party Music Guide: Ultimate Tips for the Perfect
# Playlist](https://thebackstage-deezer.com/music/perfect-party-music-playlist/)
# Planning a house party ? This is the read for you. When you've got your guest list, food and theme planned, the
# next step is the music . We'll help you make the ultimate playlist with the best  party anthems to set the mood.
#
# [Song Lists to Plan Your Event — Pianist for Parties - Sharon Planer](https://pianistforparties.com/songs/)
# Song ideas to help you plan music  for your wedding, corporate event or memorial service, by Event Pianist, Sharon
# Planer.
#
# Out: None
# [Step 1: Duration 32.75 seconds| Input tokens: 2,093 | Output tokens: 4,361]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("The best music recommendation for a party at Wayne's mansion is the 'late nights in the wayne
#   manor' playlist by Bruce Wayne, available on YouTube and Spotify.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: The best music recommendation for a party at Wayne's mansion is the 'late nights in the wayne manor'
# playlist by Bruce Wayne, available on YouTube and Spotify.
# [Step 2: Duration 17.16 seconds| Input tokens: 5,102 | Output tokens: 6,596]
# "The best music recommendation for a party at Wayne's mansion is the 'late nights in the wayne manor' playlist by Bruce Wayne, available on YouTube and Spotify."

# %% [markdown]
# When you run this example, the output will **display a trace of the workflow steps being executed**. It will also print the corresponding Python code with the message:
#
# ```python
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   results = web_search(query="best music for a Batman party")
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ```
#
# After a few steps, you'll see the generated playlist that Alfred can use for the party! 🎵

# %% [markdown]
# ## Using a Custom Tool to Prepare the Menu
#
# Now that we have selected a playlist, we need to organize the menu for the guests. Again, Alfred can take advantage of `smolagents` to do so. Here, we use the `@tool` decorator to define a custom function that acts as a tool. We'll cover tool creation in more detail later, so for now, we can simply run the code.
#
# As you can see in the example below, we will create a tool using `@tool` decorator and include it in the `tools` list.

# %%
from smolagents import CodeAgent, tool

@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                        - "casual": Menu for casual party.
                        - "formal": Menu for formal party.
                        - "superhero": Menu for superhero party.
                        - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

agent = CodeAgent(tools=[suggest_menu], model=InferenceClientModel())

agent.run("Prepare a formal menu for the party.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Prepare a formal menu for the party.                                                                            │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu(occasion="formal")
#   final_answer(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3-course dinner with wine and dessert.
# [Step 1: Duration 4.18 seconds| Input tokens: 2,112 | Output tokens: 561]
# '3-course dinner with wine and dessert.'

# %% [markdown]
# The agent will run for a few steps until finding the answer.
#
# The menu is ready! 🥗

# %% [markdown]
# ## Using Python Imports Inside the Agent
#
# We have the playlist and menu ready, but we need to check one more crucial detail: preparation time!
#
# Alfred needs to calculate when everything would be ready if he started preparing now, in case they need assistance from other superheroes.
#
# `smolagents` specializes in agents that write and execute Python code snippets, offering sandboxed execution for security. It supports both open-source and proprietary language models, making it adaptable to various development environments.
#
# **Code execution has strict security measures** - imports outside a predefined safe list are blocked by default. However, you can authorize additional imports by passing them as strings in `additional_authorized_imports`.
# For more details on secure code execution, see the official [guide](https://huggingface.co/docs/smolagents/tutorials/secure_code_execution).
#
# When creating the agent, we will use `additional_authorized_imports` to allow for importing the `datetime` module.

# %%
from smolagents import CodeAgent, InferenceClientModel
import numpy as np
import time
import datetime

agent = CodeAgent(tools=[], model=InferenceClientModel(), additional_authorized_imports=['datetime'])

agent.run(
    """
    Alfred needs to prepare for the party. Here are the tasks:
    1. Prepare the drinks - 30 minutes
    2. Decorate the mansion - 60 minutes
    3. Set up the menu - 45 minutes
    3. Prepare the music and playlist - 45 minutes

    If we start right now, at what time will the party be ready?
    """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │     1. Prepare the drinks - 30 minutes                                                                          │
# │     2. Decorate the mansion - 60 minutes                                                                        │
# │     3. Set up the menu - 45 minutes                                                                             │
# │     3. Prepare the music and playlist - 45 minutes                                                              │
# │                                                                                                                 │
# │     If we start right now, at what time will the party be ready?                                                │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   total_minutes = 30 + 60 + 45 + 45
#   total_hours = total_minutes / 60
#   final_answer(f"{total_hours} hours")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3.0 hours
# [Step 1: Duration 12.72 seconds| Input tokens: 2,111 | Output tokens: 2,176]
# '3.0 hours'

# %% [markdown]
# These examples are just the beginning of what you can do with code agents, and we're already starting to see their utility for preparing the party.
# You can learn more about how to build code agents in the [smolagents documentation](https://huggingface.co/docs/smolagents).
#
# `smolagents` specializes in agents that write and execute Python code snippets, offering sandboxed execution for security. It supports both open-source and proprietary language models, making it adaptable to various development environments.

# %% [markdown]
# ## Sharing Our Custom Party Preparator Agent to the Hub
#
# Wouldn't it be **amazing to share our very own Alfred agent with the community**? By doing so, anyone can easily download and use the agent directly from the Hub, bringing the ultimate party planner of Gotham to their fingertips! Let's make it happen! 🎉
#
# The `smolagents` library makes this possible by allowing you to share a complete agent with the community and download others for immediate use. It's as simple as the following:

# %%
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel, VisitWebpageTool, FinalAnswerTool, Tool, tool

@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion: The type of occasion for the party.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

@tool
def catering_service_tool(query: str) -> str:
    """
    This tool returns the highest-rated catering service in Gotham City.

    Args:
        query: A search term for finding catering services.
    """
    # Example list of catering services and their ratings
    services = {
        "Gotham Catering Co.": 4.9,
        "Wayne Manor Catering": 4.8,
        "Gotham City Events": 4.7,
    }

    # Find the highest rated catering service (simulating search query filtering)
    best_service = max(services, key=services.get)

    return best_service

class SuperheroPartyThemeTool(Tool):
    name = "superhero_party_theme_generator"
    description = """
    This tool suggests creative superhero-themed party ideas based on a category.
    It returns a unique party theme idea."""

    inputs = {
        "category": {
            "type": "string",
            "description": "The type of superhero party (e.g., 'classic heroes', 'villain masquerade', 'futuristic gotham').",
        }
    }

    output_type = "string"

    def forward(self, category: str):
        themes = {
            "classic heroes": "Justice League Gala: Guests come dressed as their favorite DC heroes with themed cocktails like 'The Kryptonite Punch'.",
            "villain masquerade": "Gotham Rogues' Ball: A mysterious masquerade where guests dress as classic Batman villains.",
            "futuristic gotham": "Neo-Gotham Night: A cyberpunk-style party inspired by Batman Beyond, with neon decorations and futuristic gadgets."
        }

        return themes.get(category.lower(), "Themed party idea not found. Try 'classic heroes', 'villain masquerade', or 'futuristic gotham'.")


# Alfred, the butler, preparing the menu for the party
agent = CodeAgent(
    tools=[
        WebSearchTool(),
        VisitWebpageTool(),
        suggest_menu,
        catering_service_tool,
        SuperheroPartyThemeTool()
        ],
    model=InferenceClientModel(),
    max_steps=10,
    verbosity_level=2
)

agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme        │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions
# (Request ID: Root=1-6953d34c-3f398ff5216c72b16d8c6eb3;1dfd2a4f-af6f-4608-b26f-cacf8c41c94c)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add
# pre-paid credits to your account.
# [Step 1: Duration 0.88 seconds]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:1654, in CodeAgent._step_stream(self, memory_step)
#    1653 else:
# -> 1654     chat_message: ChatMessage = self.model.generate(
#    1655         input_messages,
#    1656         stop_sequences=stop_sequences,
#    1657         **additional_args,
#    1658     )
#    1659     memory_step.model_output_message = chat_message
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\models.py:1538, in InferenceClientModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1537 self._apply_rate_limit()
# -> 1538 response = self.retryer(self.client.chat_completion, **completion_kwargs)
#    1539 content = response.choices[0].message.content
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\utils.py:542, in Retrying.__call__(self, fn, *args, **kwargs)
#     541 try:
# --> 542     result = fn(*args, **kwargs)
#     544     # Log after successful call if we had retries
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:919, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     912 request_parameters = provider_helper.prepare_request(
#     913     inputs=messages,
#     914     parameters=parameters,
#    (...)    917     api_key=self.token,
#     918 )
# --> 919 data = self._inner_post(request_parameters, stream=stream)
#     921 if stream:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:275, in InferenceClient._inner_post(self, request_parameters, stream)
#     274 try:
# --> 275     hf_raise_for_status(response)
#     276     return response.iter_lines() if stream else response.content
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions (Request ID: Root=1-6953d34c-3f398ff5216c72b16d8c6eb3;1dfd2a4f-af6f-4608-b26f-cacf8c41c94c)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add pre-paid credits to your account.
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[4], line 78
#      64 # Alfred, the butler, preparing the menu for the party
#      65 agent = CodeAgent(
#      66     tools=[
#      67         WebSearchTool(),
#    (...)     75     verbosity_level=2
#      76 )
# ---> 78 agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:498, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     495     return self._run_stream(task=self.task, max_steps=max_steps, images=images)
#     497 run_start_time = time.time()
# --> 498 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500 # Outputs are returned only at the end. We only look at the last step.
#     501 assert isinstance(steps[-1], FinalAnswerStep)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:595, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     591             action_step.is_final_answer = True
#     593 except AgentGenerationError as e:
#     594     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 595     raise e
#     596 except AgentError as e:
#     597     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     598     action_step.error = e
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:577, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     575 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     576 try:
# --> 577     for output in self._step_stream(action_step):
#     578         # Yield all
#     579         yield output
#     581         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:1677, in CodeAgent._step_stream(self, memory_step)
#    1675     memory_step.model_output = output_text
#    1676 except Exception as e:
# -> 1677     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1679 ### Parse output ###
#    1680 try:
#
# AgentGenerationError: Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions (Request ID: Root=1-6953d34c-3f398ff5216c72b16d8c6eb3;1dfd2a4f-af6f-4608-b26f-cacf8c41c94c)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add pre-paid credits to your account.

# %%
agent.push_to_hub('bprs6869/AlfredAgent')
# Out:
# README.md:   0%|          | 0.00/231 [00:00<?, ?B/s]
# c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\bhask\.cache\huggingface\hub\spaces--bprs6869--AlfredAgent. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# This agent has step_callbacks: they will be ignored by this method. 1
# CommitInfo(commit_url='https://huggingface.co/spaces/bprs6869/AlfredAgent/commit/121fcdada334e4d9f587d645a2256cb1585f7141', commit_message='Upload agent', commit_description='', oid='121fcdada334e4d9f587d645a2256cb1585f7141', pr_url=None, repo_url=RepoUrl('https://huggingface.co/spaces/bprs6869/AlfredAgent', endpoint='https://huggingface.co', repo_type='space', repo_id='bprs6869/AlfredAgent'), pr_revision=None, pr_num=None)

# %% [markdown]
# To download the agent again, use the code below:

# %%
agent = CodeAgent(tools=[], model=InferenceClientModel())
alfred_agent = agent.from_hub('bprs6869/AlfredAgent', trust_remote_code=True)
# Out:
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# app.py: 0.00B [00:00, ?B/s]
# requirements.txt:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md:   0%|          | 0.00/273 [00:00<?, ?B/s]
# agent.json: 0.00B [00:00, ?B/s]
# prompts.yaml: 0.00B [00:00, ?B/s]
# catering_service_tool.py:   0%|          | 0.00/975 [00:00<?, ?B/s]
# final_answer.py:   0%|          | 0.00/462 [00:00<?, ?B/s]
# suggest_menu.py:   0%|          | 0.00/848 [00:00<?, ?B/s]
# web_search.py: 0.00B [00:00, ?B/s]
# superhero_party_theme_generator.py: 0.00B [00:00, ?B/s]
# visit_webpage.py: 0.00B [00:00, ?B/s]

# %%
alfred_agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme        │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions
# (Request ID: Root=1-6953d379-4d33a89820ad8c5b2b39d529;2fb5c4fb-0da4-4349-91cb-8e317b51cc80)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add
# pre-paid credits to your account.
# [Step 1: Duration 0.31 seconds]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:1654, in CodeAgent._step_stream(self, memory_step)
#    1653 else:
# -> 1654     chat_message: ChatMessage = self.model.generate(
#    1655         input_messages,
#    1656         stop_sequences=stop_sequences,
#    1657         **additional_args,
#    1658     )
#    1659     memory_step.model_output_message = chat_message
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\models.py:1538, in InferenceClientModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1537 self._apply_rate_limit()
# -> 1538 response = self.retryer(self.client.chat_completion, **completion_kwargs)
#    1539 content = response.choices[0].message.content
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\utils.py:542, in Retrying.__call__(self, fn, *args, **kwargs)
#     541 try:
# --> 542     result = fn(*args, **kwargs)
#     544     # Log after successful call if we had retries
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:919, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     912 request_parameters = provider_helper.prepare_request(
#     913     inputs=messages,
#     914     parameters=parameters,
#    (...)    917     api_key=self.token,
#     918 )
# --> 919 data = self._inner_post(request_parameters, stream=stream)
#     921 if stream:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:275, in InferenceClient._inner_post(self, request_parameters, stream)
#     274 try:
# --> 275     hf_raise_for_status(response)
#     276     return response.iter_lines() if stream else response.content
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions (Request ID: Root=1-6953d379-4d33a89820ad8c5b2b39d529;2fb5c4fb-0da4-4349-91cb-8e317b51cc80)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add pre-paid credits to your account.
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 alfred_agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:498, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     495     return self._run_stream(task=self.task, max_steps=max_steps, images=images)
#     497 run_start_time = time.time()
# --> 498 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500 # Outputs are returned only at the end. We only look at the last step.
#     501 assert isinstance(steps[-1], FinalAnswerStep)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:595, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     591             action_step.is_final_answer = True
#     593 except AgentGenerationError as e:
#     594     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 595     raise e
#     596 except AgentError as e:
#     597     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     598     action_step.error = e
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:577, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     575 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     576 try:
# --> 577     for output in self._step_stream(action_step):
#     578         # Yield all
#     579         yield output
#     581         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:1677, in CodeAgent._step_stream(self, memory_step)
#    1675     memory_step.model_output = output_text
#    1676 except Exception as e:
# -> 1677     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1679 ### Parse output ###
#    1680 try:
#
# AgentGenerationError: Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions (Request ID: Root=1-6953d379-4d33a89820ad8c5b2b39d529;2fb5c4fb-0da4-4349-91cb-8e317b51cc80)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add pre-paid credits to your account.

# %% [markdown]
# What's also exciting is that shared agents are directly available as Hugging Face Spaces, allowing you to interact with them in real-time. You can explore other agents [here](https://huggingface.co/spaces/davidberenstein1957/smolagents-and-tools).
#
# For example, the _AlfredAgent_ is available [here](https://huggingface.co/spaces/sergiopaniego/AlfredAgent).

# %% [markdown]
# ### Inspecting Our Party Preparator Agent with OpenTelemetry and Langfuse 📡
#
# Full trace can be found [here](https://cloud.langfuse.com/project/cm7bq0abj025rad078ak3luwi/traces/995fc019255528e4f48cf6770b0ce27b?timestamp=2025-02-19T10%3A28%3A36.929Z).
#
# As Alfred fine-tunes the Party Preparator Agent, he's growing weary of debugging its runs. Agents, by nature, are unpredictable and difficult to inspect. But since he aims to build the ultimate Party Preparator Agent and deploy it in production, he needs robust traceability for future monitoring and analysis.
#
# Once again, `smolagents` comes to the rescue! It embraces the [OpenTelemetry](https://opentelemetry.io/) standard for instrumenting agent runs, allowing seamless inspection and logging. With the help of [Langfuse](https://langfuse.com/) and the `SmolagentsInstrumentor`, Alfred can easily track and analyze his agent’s behavior.
#
# Setting it up is straightforward!
#
# First, we need to install the necessary dependencies:

# %%
# !pip install smolagents[telemetry] opentelemetry-sdk opentelemetry-exporter-otlp openinference-instrumentation-smolagents
# Out:
# ^C
# Collecting opentelemetry-sdk
#   Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp
#   Downloading opentelemetry_exporter_otlp-1.39.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting openinference-instrumentation-smolagents
#   Downloading openinference_instrumentation_smolagents-0.1.21-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: smolagents[telemetry] in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (1.23.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents[telemetry]) (0.35.0)
# Requirement already satisfied: requests>=2.32.3 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents[telemetry]) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents[telemetry]) (14.1.0)
# Requirement already satisfied: jinja2>=3.1.4 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents[telemetry]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents[telemetry]) (11.1.0)
# Requirement already satisfied: python-dotenv in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from smolagents[telemetry]) (1.1.1)
# Collecting arize-phoenix (from smolagents[telemetry])
#   Downloading arize_phoenix-12.27.0-py3-none-any.whl.metadata (36 kB)
# Collecting opentelemetry-api==1.39.1 (from opentelemetry-sdk)
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk)
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from opentelemetry-sdk) (4.15.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from opentelemetry-api==1.39.1->opentelemetry-sdk) (8.7.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.39.1 (from opentelemetry-exporter-otlp)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.39.1 (from opentelemetry-exporter-otlp)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp)
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting grpcio<2.0.0,>=1.66.2 (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp)
#   Using cached grpcio-1.76.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp)
#   Downloading opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf<7.0,>=5.0 (from opentelemetry-proto==1.39.1->opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp)
#   Using cached protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting openinference-instrumentation>=0.1.27 (from openinference-instrumentation-smolagents)
#   Downloading openinference_instrumentation-0.1.42-py3-none-any.whl.metadata (5.0 kB)
# Collecting openinference-semantic-conventions>=0.1.17 (from openinference-instrumentation-smolagents)
#   Downloading openinference_semantic_conventions-0.1.25-py3-none-any.whl.metadata (1.3 kB)
# Collecting opentelemetry-instrumentation (from openinference-instrumentation-smolagents)
#   Downloading opentelemetry_instrumentation-0.60b1-py3-none-any.whl.metadata (7.2 kB)
# Collecting wrapt (from openinference-instrumentation-smolagents)
#   Downloading wrapt-2.0.1-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: filelock in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[telemetry]) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[telemetry]) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[telemetry]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[telemetry]) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[telemetry]) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from jinja2>=3.1.4->smolagents[telemetry]) (3.0.3)
#   Downloading wrapt-1.17.3-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents[telemetry]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents[telemetry]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents[telemetry]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from requests>=2.32.3->smolagents[telemetry]) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from rich>=13.9.4->smolagents[telemetry]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from rich>=13.9.4->smolagents[telemetry]) (2.19.2)
# Collecting aioitertools (from arize-phoenix->smolagents[telemetry])
#   Downloading aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiosqlite (from arize-phoenix->smolagents[telemetry])
#   Downloading aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting alembic<2,>=1.3.0 (from arize-phoenix->smolagents[telemetry])
#   Downloading alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting arize-phoenix-client>=1.27.1 (from arize-phoenix->smolagents[telemetry])
#   Downloading arize_phoenix_client-1.27.1-py3-none-any.whl.metadata (11 kB)
# Collecting arize-phoenix-evals>=2.7.1 (from arize-phoenix->smolagents[telemetry])
#   Downloading arize_phoenix_evals-2.7.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting arize-phoenix-otel>=0.14.0 (from arize-phoenix->smolagents[telemetry])
#   Downloading arize_phoenix_otel-0.14.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting authlib (from arize-phoenix->smolagents[telemetry])
#   Downloading authlib-1.6.6-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting cachetools (from arize-phoenix->smolagents[telemetry])
#   Using cached cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting email-validator (from arize-phoenix->smolagents[telemetry])
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: fastapi in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (0.118.0)
# Collecting grpc-interceptor (from arize-phoenix->smolagents[telemetry])
#   Downloading grpc_interceptor-0.15.4-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: httpx in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (0.28.1)
# Collecting jmespath (from arize-phoenix->smolagents[telemetry])
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting ldap3 (from arize-phoenix->smolagents[telemetry])
#   Downloading ldap3-2.9.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=2.0.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (2.3.3)
# Requirement already satisfied: orjson in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (3.11.3)
# Requirement already satisfied: pandas>=1.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (2.3.3)
# Collecting prometheus-client (from arize-phoenix->smolagents[telemetry])
#   Downloading prometheus_client-0.23.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: psutil in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (7.1.0)
# Collecting pyarrow (from arize-phoenix->smolagents[telemetry])
#   Downloading pyarrow-22.0.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic>=2.1.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (2.11.9)
# Requirement already satisfied: python-dateutil in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (2.9.0.post0)
# Requirement already satisfied: python-multipart in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (0.0.20)
# Collecting scikit-learn (from arize-phoenix->smolagents[telemetry])
#   Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from arize-phoenix->smolagents[telemetry])
#   Downloading scipy-1.16.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting sqlalchemy<3,>=2.0.4 (from sqlalchemy[asyncio]<3,>=2.0.4->arize-phoenix->smolagents[telemetry])
#   Downloading sqlalchemy-2.0.45-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting sqlean-py<3.50,>=3.45.1 (from arize-phoenix->smolagents[telemetry])
#   Downloading sqlean_py-3.49.1-cp313-cp313-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: starlette in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (0.48.0)
# Collecting strawberry-graphql==0.287.3 (from arize-phoenix->smolagents[telemetry])
#   Downloading strawberry_graphql-0.287.3-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: uvicorn in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from arize-phoenix->smolagents[telemetry]) (0.37.0)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql==0.287.3->arize-phoenix->smolagents[telemetry])
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting lia-web>=0.2.1 (from strawberry-graphql==0.287.3->arize-phoenix->smolagents[telemetry])
#   Downloading lia_web-0.3.1-py3-none-any.whl.metadata (1.2 kB)
# Collecting Mako (from alembic<2,>=1.3.0->arize-phoenix->smolagents[telemetry])
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonpath-ng (from arize-phoenix-evals>=2.7.1->arize-phoenix->smolagents[telemetry])
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting pystache (from arize-phoenix-evals>=2.7.1->arize-phoenix->smolagents[telemetry])
#   Downloading pystache-0.6.8-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: zipp>=3.20 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api==1.39.1->opentelemetry-sdk) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[telemetry]) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from pandas>=1.0->arize-phoenix->smolagents[telemetry]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from pandas>=1.0->arize-phoenix->smolagents[telemetry]) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from pydantic>=2.1.0->arize-phoenix->smolagents[telemetry]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from pydantic>=2.1.0->arize-phoenix->smolagents[telemetry]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from pydantic>=2.1.0->arize-phoenix->smolagents[telemetry]) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from python-dateutil->arize-phoenix->smolagents[telemetry]) (1.17.0)
# Collecting greenlet>=1 (from sqlalchemy<3,>=2.0.4->sqlalchemy[asyncio]<3,>=2.0.4->arize-phoenix->smolagents[telemetry])
#   Downloading greenlet-3.3.0-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: colorama in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.31.2->smolagents[telemetry]) (0.4.6)
# Collecting cryptography (from authlib->arize-phoenix->smolagents[telemetry])
#   Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting dnspython>=2.0.0 (from email-validator->arize-phoenix->smolagents[telemetry])
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from starlette->arize-phoenix->smolagents[telemetry]) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from httpx->arize-phoenix->smolagents[telemetry]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from httpcore==1.*->httpx->arize-phoenix->smolagents[telemetry]) (0.16.0)
# Collecting pyasn1>=0.4.6 (from ldap3->arize-phoenix->smolagents[telemetry])
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting joblib>=1.3.0 (from scikit-learn->arize-phoenix->smolagents[telemetry])
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->arize-phoenix->smolagents[telemetry])
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=7.0 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from uvicorn->arize-phoenix->smolagents[telemetry]) (8.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\bhask\onedrive\documents\learning\huggingface ai agents's course\venv\lib\site-packages (from anyio<5,>=3.6.2->starlette->arize-phoenix->smolagents[telemetry]) (1.3.1)
# Collecting cross-web>=0.3.0 (from lia-web>=0.2.1->strawberry-graphql==0.287.3->arize-phoenix->smolagents[telemetry])
#   Downloading cross_web-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cffi>=2.0.0 (from cryptography->authlib->arize-phoenix->smolagents[telemetry])
#   Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting ply (from jsonpath-ng->arize-phoenix-evals>=2.7.1->arize-phoenix->smolagents[telemetry])
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting pycparser (from cffi>=2.0.0->cryptography->authlib->arize-phoenix->smolagents[telemetry])
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Downloading opentelemetry_exporter_otlp-1.39.1-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Downloading openinference_instrumentation_smolagents-0.1.21-py3-none-any.whl (13 kB)
# Downloading openinference_instrumentation-0.1.42-py3-none-any.whl (30 kB)
# Downloading openinference_semantic_conventions-0.1.25-py3-none-any.whl (10 kB)
# Downloading wrapt-1.17.3-cp313-cp313-win_amd64.whl (38 kB)
# Downloading arize_phoenix-12.27.0-py3-none-any.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------- ----------------------- 1.0/2.6 MB 16.9 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 3.9 MB/s eta 0:00:00
# Downloading strawberry_graphql-0.287.3-py3-none-any.whl (309 kB)
# Downloading opentelemetry_instrumentation-0.60b1-py3-none-any.whl (33 kB)
# Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
# Downloading arize_phoenix_client-1.27.1-py3-none-any.whl (148 kB)
# Downloading arize_phoenix_evals-2.7.1-py3-none-any.whl (156 kB)
# Downloading arize_phoenix_otel-0.14.0-py3-none-any.whl (17 kB)
# Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached grpcio-1.76.0-cp313-cp313-win_amd64.whl (4.7 MB)
# Using cached protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Downloading sqlalchemy-2.0.45-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 15.8 MB/s eta 0:00:00
# Downloading sqlean_py-3.49.1-cp313-cp313-win_amd64.whl (804 kB)
#    ---------------------------------------- 0.0/804.3 kB ? eta -:--:--
#    --------------------------------------- 804.3/804.3 kB 14.5 MB/s eta 0:00:00
# Downloading aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Downloading aiosqlite-0.22.1-py3-none-any.whl (17 kB)
# Downloading authlib-1.6.6-py2.py3-none-any.whl (244 kB)
# Using cached cachetools-6.2.4-py3-none-any.whl (11 kB)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading grpc_interceptor-0.15.4-py3-none-any.whl (20 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading ldap3-2.9.1-py2.py3-none-any.whl (432 kB)
# Downloading prometheus_client-0.23.1-py3-none-any.whl (61 kB)
# Downloading pyarrow-22.0.0-cp313-cp313-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    ---- ----------------------------------- 3.4/28.0 MB 17.0 MB/s eta 0:00:02
#    --------- ------------------------------ 6.8/28.0 MB 16.0 MB/s eta 0:00:02
#    ------------- -------------------------- 9.2/28.0 MB 14.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 12.1/28.0 MB 14.5 MB/s eta 0:00:02
#    --------------------- ------------------ 14.9/28.0 MB 14.2 MB/s eta 0:00:01
#    ------------------------- -------------- 17.6/28.0 MB 14.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 20.4/28.0 MB 13.8 MB/s eta 0:00:01
#    --------------------------------- ------ 23.3/28.0 MB 13.7 MB/s eta 0:00:01
#    ------------------------------------ --- 25.7/28.0 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------  27.8/28.0 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 13.3 MB/s eta 0:00:00
# Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --------------- ------------------------ 3.1/8.0 MB 16.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 13.5 MB/s eta 0:00:00
# Downloading scipy-1.16.3-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    --- ------------------------------------ 3.1/38.5 MB 15.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.8/38.5 MB 14.0 MB/s eta 0:00:03
#    -------- ------------------------------- 8.4/38.5 MB 13.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.0/38.5 MB 13.4 MB/s eta 0:00:03
#    -------------- ------------------------- 13.6/38.5 MB 13.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.3/38.5 MB 13.3 MB/s eta 0:00:02
#    ------------------- -------------------- 18.9/38.5 MB 13.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.8/38.5 MB 13.2 MB/s eta 0:00:02
#    ------------------------- -------------- 24.4/38.5 MB 13.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.0/38.5 MB 13.1 MB/s eta 0:00:01
#    ------------------------------- -------- 29.9/38.5 MB 13.1 MB/s eta 0:00:01
#    --------------------------------- ------ 32.5/38.5 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.5 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.5 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 12.8 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading greenlet-3.3.0-cp313-cp313-win_amd64.whl (301 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading lia_web-0.3.1-py3-none-any.whl (5.9 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading pystache-0.6.8-py3-none-any.whl (82 kB)
# Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Downloading cross_web-0.4.0-py3-none-any.whl (14 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: ply, wrapt, threadpoolctl, sqlean-py, scipy, pystache, pycparser, pyasn1, pyarrow, protobuf, prometheus-client, openinference-semantic-conventions, Mako, jsonpath-ng, joblib, jmespath, grpcio, greenlet, graphql-core, dnspython, cross-web, cachetools, aiosqlite, aioitertools, sqlalchemy, scikit-learn, opentelemetry-proto, opentelemetry-api, lia-web, ldap3, grpc-interceptor, googleapis-common-protos, email-validator, cffi, strawberry-graphql, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, cryptography, alembic, opentelemetry-sdk, opentelemetry-instrumentation, authlib, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, openinference-instrumentation, opentelemetry-exporter-otlp, openinference-instrumentation-smolagents, arize-phoenix-evals, arize-phoenix-otel, arize-phoenix-client, arize-phoenix
# Successfully installed Mako-1.3.10 aioitertools-0.13.0 aiosqlite-0.22.1 alembic-1.17.2 arize-phoenix-12.27.0 arize-phoenix-client-1.27.1 arize-phoenix-evals-2.7.1 arize-phoenix-otel-0.14.0 authlib-1.6.6 cachetools-6.2.4 cffi-2.0.0 cross-web-0.4.0 cryptography-46.0.3 dnspython-2.8.0 email-validator-2.3.0 googleapis-common-protos-1.72.0 graphql-core-3.2.7 greenlet-3.3.0 grpc-interceptor-0.15.4 grpcio-1.76.0 jmespath-1.0.1 joblib-1.5.3 jsonpath-ng-1.7.0 ldap3-2.9.1 lia-web-0.3.1 openinference-instrumentation-0.1.42 openinference-instrumentation-smolagents-0.1.21 openinference-semantic-conventions-0.1.25 opentelemetry-api-1.39.1 opentelemetry-exporter-otlp-1.39.1 opentelemetry-exporter-otlp-proto-common-1.39.1 opentelemetry-exporter-otlp-proto-grpc-1.39.1 opentelemetry-exporter-otlp-proto-http-1.39.1 opentelemetry-instrumentation-0.60b1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 ply-3.11 prometheus-client-0.23.1 protobuf-6.33.2 pyarrow-22.0.0 pyasn1-0.6.1 pycparser-2.23 pystache-0.6.8 scikit-learn-1.8.0 scipy-1.16.3 sqlalchemy-2.0.45 sqlean-py-3.49.1 strawberry-graphql-0.287.3 threadpoolctl-3.6.0 wrapt-1.17.3
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Next, Alfred has already created an account on Langfuse and has his API keys ready. If you haven’t done so yet, you can sign up for Langfuse Cloud [here](https://cloud.langfuse.com/) or explore [alternatives](https://huggingface.co/docs/smolagents/tutorials/inspect_runs).
#
# Once you have your API keys, they need to be properly configured as follows:

# %%
import os
import base64
from dotenv import load_dotenv
load_dotenv()

LANGFUSE_PUBLIC_KEY=os.environ.get('LANGFUSE_PUBLIC_KEY')
LANGFUSE_SECRET_KEY=os.environ.get("LANGFUSE_PUBLIC_KEY")
LANGFUSE_AUTH=base64.b64encode(f"{LANGFUSE_PUBLIC_KEY}:{LANGFUSE_SECRET_KEY}".encode()).decode()

os.environ["OTEL_EXPORTER_OTLP_ENDPOINT"] = "https://cloud.langfuse.com/api/public/otel" # EU data region
# os.environ["OTEL_EXPORTER_OTLP_ENDPOINT"] = "https://us.cloud.langfuse.com/api/public/otel" # US data region
os.environ["OTEL_EXPORTER_OTLP_HEADERS"] = f"Authorization=Basic {LANGFUSE_AUTH}"

# %% [markdown]
# Finally, Alfred is ready to initialize the `SmolagentsInstrumentor` and start tracking his agent's performance.

# %%
from opentelemetry.sdk.trace import TracerProvider

from openinference.instrumentation.smolagents import SmolagentsInstrumentor
from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
from opentelemetry.sdk.trace.export import SimpleSpanProcessor

trace_provider = TracerProvider()
trace_provider.add_span_processor(SimpleSpanProcessor(OTLPSpanExporter()))

SmolagentsInstrumentor().instrument(tracer_provider=trace_provider)

# %% [markdown]
# Alfred is now connected 🔌! The runs from `smolagents` are being logged in Langfuse, giving him full visibility into the agent's behavior. With this setup, he's ready to revisit previous runs and refine his Party Preparator Agent even further.

# %%
from smolagents import CodeAgent, InferenceClientModel

agent = CodeAgent(tools=[], model=InferenceClientModel())
alfred_agent = agent.from_hub('bprs6869/AlfredAgent', trust_remote_code=True)
alfred_agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
# Out:
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme        │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Failed to export span batch code: 401, reason: {"message":"Invalid credentials. Confirm that you've configured the correct host."}
# Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions
# (Request ID: Root=1-6953d405-5331d61271d3ae964866d222;aa387758-bb74-492d-8e2c-de5cc3a34860)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add
# pre-paid credits to your account.
# Failed to export span batch code: 401, reason: {"message":"Invalid credentials. Confirm that you've configured the correct host."}
# [Step 1: Duration 1.83 seconds]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:1654, in CodeAgent._step_stream(self, memory_step)
#    1653 else:
# -> 1654     chat_message: ChatMessage = self.model.generate(
#    1655         input_messages,
#    1656         stop_sequences=stop_sequences,
#    1657         **additional_args,
#    1658     )
#    1659     memory_step.model_output_message = chat_message
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\openinference\instrumentation\smolagents\_wrappers.py:449, in _ModelWrapper.__call__(self, wrapped, instance, args, kwargs)
#     439 with self._tracer.start_as_current_span(
#     440     span_name,
#     441     attributes={
#    (...)    447     },
#     448 ) as span:
# --> 449     output_message = wrapped(*args, **kwargs)
#     450     span.set_status(trace_api.StatusCode.OK)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\models.py:1538, in InferenceClientModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1537 self._apply_rate_limit()
# -> 1538 response = self.retryer(self.client.chat_completion, **completion_kwargs)
#    1539 content = response.choices[0].message.content
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\utils.py:542, in Retrying.__call__(self, fn, *args, **kwargs)
#     541 try:
# --> 542     result = fn(*args, **kwargs)
#     544     # Log after successful call if we had retries
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:919, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     912 request_parameters = provider_helper.prepare_request(
#     913     inputs=messages,
#     914     parameters=parameters,
#    (...)    917     api_key=self.token,
#     918 )
# --> 919 data = self._inner_post(request_parameters, stream=stream)
#     921 if stream:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\inference\_client.py:275, in InferenceClient._inner_post(self, request_parameters, stream)
#     274 try:
# --> 275     hf_raise_for_status(response)
#     276     return response.iter_lines() if stream else response.content
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\huggingface_hub\utils\_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions (Request ID: Root=1-6953d405-5331d61271d3ae964866d222;aa387758-bb74-492d-8e2c-de5cc3a34860)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add pre-paid credits to your account.
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[12], line 5
#       3 agent = CodeAgent(tools=[], model=InferenceClientModel())
#       4 alfred_agent = agent.from_hub('bprs6869/AlfredAgent', trust_remote_code=True)
# ----> 5 alfred_agent.run("Give me best playlist for a party at the Wayne's mansion. The party idea is a 'villain masquerade' theme")
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\openinference\instrumentation\smolagents\_wrappers.py:142, in _RunWrapper.__call__(self, wrapped, instance, args, kwargs)
#     139 agent_output = []
#     141 try:
# --> 142     agent_output = wrapped(*args, **kwargs)
#     143 except Exception as e:
#     144     span.record_exception(e)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:498, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     495     return self._run_stream(task=self.task, max_steps=max_steps, images=images)
#     497 run_start_time = time.time()
# --> 498 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500 # Outputs are returned only at the end. We only look at the last step.
#     501 assert isinstance(steps[-1], FinalAnswerStep)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:595, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     591             action_step.is_final_answer = True
#     593 except AgentGenerationError as e:
#     594     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 595     raise e
#     596 except AgentError as e:
#     597     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     598     action_step.error = e
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:577, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     575 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     576 try:
# --> 577     for output in self._step_stream(action_step):
#     578         # Yield all
#     579         yield output
#     581         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\openinference\instrumentation\smolagents\_wrappers.py:311, in _StepWrapper.__call__(self, wrapped, instance, args, kwargs)
#     302 with self._tracer.start_as_current_span(
#     303     span_name,
#     304     attributes={
#    (...)    308     },
#     309 ) as span:
#     310     try:
# --> 311         yield from wrapped(*args, **kwargs)
#     312     except Exception as execution_error:
#     313         span.record_exception(execution_error)
#
# File c:\Users\bhask\OneDrive\Documents\Learning\Huggingface AI Agents's Course\venv\Lib\site-packages\smolagents\agents.py:1677, in CodeAgent._step_stream(self, memory_step)
#    1675     memory_step.model_output = output_text
#    1676 except Exception as e:
# -> 1677     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1679 ### Parse output ###
#    1680 try:
#
# AgentGenerationError: Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/novita/v3/openai/chat/completions (Request ID: Root=1-6953d405-5331d61271d3ae964866d222;aa387758-bb74-492d-8e2c-de5cc3a34860)
#
# You have reached the free monthly usage limit for novita. Subscribe to PRO to get 20x more included usage, or add pre-paid credits to your account.

# %% [markdown]
# Alfred can now access this logs [here](https://cloud.langfuse.com/project/cm7bq0abj025rad078ak3luwi/traces/995fc019255528e4f48cf6770b0ce27b?timestamp=2025-02-19T10%3A28%3A36.929Z) to review and analyze them.
#
# Meanwhile, the [suggested playlist](https://open.spotify.com/playlist/0gZMMHjuxMrrybQ7wTMTpw) sets the perfect vibe for the party preparations. Cool, right? 🎶
