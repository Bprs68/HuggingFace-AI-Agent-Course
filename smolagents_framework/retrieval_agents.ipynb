# %%
from smolagents import LiteLLMModel, DuckDuckGoSearchTool, CodeAgent, FinalAnswerTool

# initialize the search tool
search_tool = DuckDuckGoSearchTool()

# initialising local model
model = LiteLLMModel(
    model_id="ollama_chat/qwen2.5-coder:7b",
    api_base="http://127.0.0.1:11434",
    max_tokens=2048,
    num_ctx=8192

)

# define agent with search tool
agent = CodeAgent(
    model=model,
    tools=[search_tool, FinalAnswerTool()],
)

# example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama_chat/qwen2.5-coder:7b ───────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   results = web_search(query="luxury superhero-themed party ideas")
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Superhero Theme Party Ideas for Adults to Create an
# ...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Sep 20, 2024 · Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed party
# for adults! Explore creative costume ideas, vibrant decorations, and mouthwatering themed snacks and drinks .
#
# [30+ Superhero Party Ideas - Canva](https://www.canva.com/ideas/superhero-party-ideas/)
# Browse a wide range of superhero party ideas and inspiration, from photos and templates in a stunning selection of
# styles and colours.
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Superhero party ideas by an award winning professional party planner including ideas for invitations, party food &
# drinks, decorations, and party supplies
#
# [Creative Superhero Party Decor -
# Pinterest](https://www.pinterest.com/ideas/creative-superhero-party-decor/936700496672/)
# Discover Pinterest’s best ideas and inspiration for Creative superhero party decor. Get inspired and try out new
# things. Last updated 22h Teen Superhero Birthday Party Ideas Kids Superhero Birthday Decor Creative Superhero Party
# Decor Kids Superhero Party Inspiration Adult Superhero Party Superhero-themed Birthday Party Table Marvel Birthday
# ...
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# With careful planning, attention to detail, and the right party supplies, you can create an unforgettable
# experience for your guests. So, assemble your Avengers, gather your Guardians of the Galaxy, and prepare for a
# super-powered celebration that will leave everyone feeling like true heroes.
#
# [10 Best Superhero Birthday Party Ideas To Plan in
# 2025](https://www.birthdayinspire.com/superhero-birthday-party-ideas/)
# Jul 11, 2025 · There are many things that involve in planning a party like theme , decorations, costumes, games and
# activities. Here i have tried my best to cover everything you need to know to plan a perfect superhero birthday
# party . So stay tuned and enjoy the ideas mentioned below: 1. Superhero themes .
#
# [Superhero Party Theme - The Bash](https://www.thebash.com/themes/superhero)
# Get inspired by your favorite Marvel or DC Comics superhero for this fun costume party theme .
#
# [23 Awesome Costume Party Ideas for Large-Scale Events](https://www.eventbrite.com/blog/costume-party-ideas/)
# When crafting adult costume party ideas and themes, you want to create a fun-filled, exciting fest that allows
# party guests to express their inner ...
#
# [Party Stripper Ideas for a Superhero or Fantasy Theme
# |](https://defollower.com/1294/party-stripper-ideas-for-a-superhero-or-fantasy-theme/)
# Party Stripper Ideas for a Superhero or Fantasy Theme ... By choosing the ideal service and package, you can create
# an thrilling bachelor party that ...
#
# [23 Best Ideas Superheroes Halloween Party Ideas –
# Home,](https://theboiledpeanuts.com/superheroes-halloween-party-ideas/)
# Best Superheroes Halloween Party Ideas from Superhero Themed Tradeshow Booth Superhero themed party . ...
# Superheroes Halloween Party Ideas from ...
#
# Out: None
# [Step 1: Duration 18.26 seconds| Input tokens: 2,091 | Output tokens: 60]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extracting specific information from the web search results
#   superhero_party_ideas = [
#       "Decorations: Marvel and DC Comics superhero banners, posters, and balloons",
#       "Entertainment: Superhero-themed games like 'Capture the Shield', 'Who Am I?', and karaoke with
#   superhero-themed songs",
#       "Catering: Menu items such as Spider-Man pizza slices, Iron Man chicken nuggets, and Captain America
#   pancakes"
#   ]
#
#   # Joining all ideas into a single string
#   final_output = "\n".join(superhero_party_ideas)
#
#   # Providing the final answer using the `final_answer` tool
#   final_answer(final_output)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Decorations: Marvel and DC Comics superhero banners, posters, and balloons
# Entertainment: Superhero-themed games like 'Capture the Shield', 'Who Am I?', and karaoke with superhero-themed
# songs
# Catering: Menu items such as Spider-Man pizza slices, Iron Man chicken nuggets, and Captain America pancakes
# [Step 2: Duration 26.53 seconds| Input tokens: 5,024 | Output tokens: 229]
# Decorations: Marvel and DC Comics superhero banners, posters, and balloons
# Entertainment: Superhero-themed games like 'Capture the Shield', 'Who Am I?', and karaoke with superhero-themed songs
# Catering: Menu items such as Spider-Man pizza slices, Iron Man chicken nuggets, and Captain America pancakes

# %% [markdown]
# ### Custom Knowledge Base Tool
#
# For specialized tasks, a custom knowledge base can be invaluable. Let’s create a tool that queries a vector database of technical documentation or specialized knowledge. Using semantic search, the agent can find the most relevant information for Alfred’s needs.
#
# A vector database stores numerical representations (embeddings) of text or other data, created by machine learning models. It enables semantic search by identifying similar meanings in high-dimensional space.
#
# This approach combines predefined knowledge with semantic search to provide context-aware solutions for event planning. With specialized knowledge access, Alfred can perfect every detail of the party.
#
# In this example, we’ll create a tool that retrieves party planning ideas from a custom knowledge base. We’ll use a BM25 retriever to search the knowledge base and return the top results, and RecursiveCharacterTextSplitter to split the documents into smaller chunks for more efficient search.

# %%
# import libraries and tools
from langchain_community.docstore.document import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever

# %%
# Creating a subclass of tool to create a tool as a class
class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning idead for Alfred's superhero-themed party at Wayne Manor"
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }

    type = "string"
    output_type = 'string'

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retreiver = BM25Retriever.from_documents(
            docs, k=5 #Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retreiver.invoke(
            query
        )

        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# %%
# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)

docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# Initialize the agent
agent = CodeAgent(tools=[party_planning_retriever], model=model)

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama_chat/qwen2.5-coder:7b ───────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   superhero_party_ideas = party_planning_retriever(query="luxury superhero-themed party at Wayne Manor")
#   print(superhero_party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 1: Duration 25.70 seconds| Input tokens: 2,104 | Output tokens: 77]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Interactive VR experiences and themed catering options")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Interactive VR experiences and themed catering options
# [Step 2: Duration 27.50 seconds| Input tokens: 4,506 | Output tokens: 281]
# Interactive VR experiences and themed catering options
